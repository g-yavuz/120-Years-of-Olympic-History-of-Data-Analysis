# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df= sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df["fare"].unique() #ahhh look at that difference of fare rate
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df, x="survived", y="fare")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=df, x="survived", y="fare")
plt.show() #We have so much outliners so we need to cut some

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=df, x="survived", y="fare")
plt.ylim(0,200)
plt.show() 
#also
print(f"We have survived or not {len(df[df["fare"]>200])} people out of the graph")
# Out:
# We have survived or not 20 people out of the graph

# %%
df["age_group"]= pd.cut(
    df["age"],
    bins=[0,12,25,60,100],
    labels=["Child", "Young", "Adult", "Elder"]
)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
tableAgeSex= df.pivot_table(
    values="survived",
    index="sex",
    columns="age_group",
    aggfunc="mean",
    observed=True 
).round(2)
display(table)
# Out:
# age_group  Child  Young  Adult  Elder
# sex
# female      0.59   0.76   0.79   1.00
# male        0.57   0.11   0.21   0.11

# %%
plt.figure(figsize=(10,5))
sns.heatmap(tableAgeSex, annot=True, cmap="Blues")
plt.show()

# %%
df["FamilyMember"] = df[["parch","sibsp"]].sum(axis=1)

# %%
df["FamilyMember"].unique() #I think we can look to the heatmap again
# Out:
# array([ 1,  0,  4,  2,  6,  5,  3,  7, 10])

# %%
tableMemberSex = df.pivot_table(
    values="survived",
    index="sex",
    columns="FamilyMember",
    aggfunc="mean",
    observed=True
)
display(tableMember)
# Out:
# FamilyMember        0         1         2         3     4      5      6    7   \
# sex
# female        0.785714  0.816092  0.775510  0.842105  0.25  0.375  0.375  0.0
# male          0.155718  0.243243  0.396226  0.500000  0.00  0.000  0.250  0.0
#
# FamilyMember   10
# sex
# female        0.0
# male          0.0

# %%
plt.figure(figsize=(10,4))
sns.heatmap(tableMemberSex,annot=True, cmap="Blues")
plt.show()

# %%
tableMember = df.pivot_table(
    values="survived",
    columns="FamilyMember",
    aggfunc="mean",
    observed=True
)
display(tableMember)
plt.figure(figsize=(10,4))
sns.heatmap(tableMember,annot=True, cmap="Blues")
plt.show()
# Out:
# FamilyMember        0         1         2         3    4         5         6   \
# survived      0.303538  0.552795  0.578431  0.724138  0.2  0.136364  0.333333
#
# FamilyMember   7    10
# survived      0.0  0.0

# %%
df["deck"].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
tableDeck= df.pivot_table(
    values="survived",
    index="deck",
    aggfunc="mean",
    observed=True
)
display(tableDeck)
plt.figure(figsize=(10,6))
sns.barplot(
    data=df,
    x="deck",
    y="survived",
    order=['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    palette="magma",
    hue="sex"
)
plt.show()
# Out:
#       survived
# deck
# A     0.466667
# B     0.744681
# C     0.593220
# D     0.757576
# E     0.750000
# F     0.615385
# G     0.500000

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    data=df,
    x="deck",
    y="survived",
    order=['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    palette="magma",
    errorbar=None
)
plt.show()
# Out:
# C:\Users\gokhan\AppData\Local\Temp\ipykernel_24204\2121637713.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
#we dont have a name column :(
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df_real = pd.read_csv(url)

# %%
df_real.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#import re
#pattern = r"\,(.*?)\."
#df["Title"] = re.search(,df_real["Name"])
#This code is wrong because re.search() expects a single string but I would have liked it to be correct

# %%
pattern = r"\,(.*?)\."
df["Title"] = df_real["Name"].str.extract(pattern)

# %%
tableTitle = df.pivot_table(
    values = "survived",
    columns="Title",
    aggfunc="mean",
    observed=True    
)
display(tableTitle)
print("-"*150)
tableTitle.fillna("None")
# Out:
# Title     Capt  Col  Don        Dr  Jonkheer  Lady  Major  Master      Miss  \
# survived   0.0  0.5  0.0  0.428571       0.0   1.0    0.5   0.575  0.697802
#
# Title     Mlle  Mme        Mr    Mrs   Ms  Rev  Sir  the Countess
# survived   1.0  1.0  0.156673  0.792  1.0  0.0  1.0           1.0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Title     Capt  Col  Don        Dr  Jonkheer  Lady  Major  Master      Miss  \
# survived   0.0  0.5  0.0  0.428571       0.0   1.0    0.5   0.575  0.697802
#
# Title     Mlle  Mme        Mr    Mrs   Ms  Rev  Sir  the Countess
# survived   1.0  1.0  0.156673  0.792  1.0  0.0  1.0           1.0

# %%
plt.figure(figsize=(12,4))
sns.barplot(tableTitle)
plt.show()

# %%
display(df["fare"].mean())
plt.figure(figsize=(20,6))
sns.histplot(df["fare"])
plt.xticks(np.arange(0, 101, 10))
plt.show()
# Out:
# np.float64(32.204207968574636)

# %%
df[(df["fare"]>32) & (df["fare"]<100)]["fare"].mean()
# Out:
# np.float64(59.67893101265822)

# %%
df_elite = df[df["fare"] > 59]

plt.figure(figsize=(7, 5))
sns.countplot(data=df_elite, x="survived")
plt.show()

# %%
sns.pairplot(df,hue="sex",palette="Set1")
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=df, x="sex", hue="survived", palette="Set1")
plt.show()
