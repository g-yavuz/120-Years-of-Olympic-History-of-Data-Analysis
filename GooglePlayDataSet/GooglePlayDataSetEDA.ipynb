# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gokhan'

# %%
os.chdir(r"C:\Users\gokhan\anaconda_projects\e41505a0-f834-445f-ba84-d65c1bf4ff32")

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df["Reviews"].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
df["Reviews"].value_counts()
# Out:
# Reviews
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 885         1
# 88486       1
# 603         1
# 1195        1
# 398307      1
# Name: count, Length: 6002, dtype: int64

# %%
df_clean = df.copy()

# %%
df_clean["Reviews"].str.isnumeric().sum()
# Out:
# np.int64(10840)

# %%
df_clean["Reviews"].shape
# Out:
# (10841,)

# %%
#df_clean["Reviews"] = df_clean["Reviews"].astype(int) ValueError

# %%
df_clean[~df_clean["Reviews"].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_clean = df_clean.drop(index=10472)

# %%
df_clean["Reviews"].str.isnumeric().sum()
# Out:
# np.int64(10840)

# %%
df_clean["Reviews"].shape
# Out:
# (10840,)

# %%
df_clean["Reviews"] = df_clean["Reviews"].astype(int)

# %%
df_clean.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10836     4.5       38                 53M       5,000+  Free     0
# 10837     5.0        4                3.6M         100+  Free     0
# 10838     NaN        3                9.5M       1,000+  Free     0
# 10839     4.5      114  Varies with device       1,000+  Free     0
# 10840     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df_clean["Size"].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 470k                     1
# 975k                     1
# 980k                     1
# 404k                     1
# 420k                     1
# Name: count, Length: 461, dtype: int64

# %%
df_clean["Size"] = df_clean["Size"].str.replace("M","000")
df_clean["Size"] = df_clean["Size"].str.replace("k","")

# %%
df_clean["Size"] = df_clean["Size"].replace("Varies with device",np.nan)

# %%
df_clean["Size"] = df_clean["Size"].astype(float)

# %%
df_clean["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_clean["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
chars_to_remove = ["+",",","$"]
cols_to_clean = ["Price","Installs"]

# %%
for char in chars_to_remove:
    for col in cols_to_clean:
        df_clean[col] = df_clean[col].str.replace(char,"")

# %%
df_clean
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type Price Content Rating  \
# 0         4.1      159  19000.0     10000  Free     0       Everyone
# 1         3.9      967  14000.0    500000  Free     0       Everyone
# 2         4.7    87510      8.7   5000000  Free     0       Everyone
# 3         4.5   215644  25000.0  50000000  Free     0           Teen
# 4         4.3      967      2.8    100000  Free     0       Everyone
# ...       ...      ...      ...       ...   ...   ...            ...
# 10836     4.5       38  53000.0      5000  Free     0       Everyone
# 10837     5.0        4      3.6       100  Free     0       Everyone
# 10838     NaN        3      9.5      1000  Free     0       Everyone
# 10839     4.5      114      NaN      1000  Free     0     Mature 17+
# 10840     4.5   398307  19000.0  10000000  Free     0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10838                    Medical  January 20, 2017                 1.0
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10840 rows x 13 columns]

# %%
df_clean["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_clean["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_clean["Price"] = df_clean["Price"].astype(float)

# %%
df_clean["Installs"] = df_clean["Installs"].astype(int)

# %%
df_clean.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price
# count  9366.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05   19579.419913  1.546434e+07      1.027368
# std       0.515219  2.927761e+06   24042.062020  8.502936e+07     15.949703
# min       1.000000  0.000000e+00       1.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01       5.600000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
df_clean.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df_clean["Last Updated"] = pd.to_datetime(df_clean["Last Updated"])

# %%
df_clean.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %%
df_clean["Year"] = df_clean["Last Updated"].dt.year

# %%
df_clean.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10836     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10837     5.0        4      3.6       100  Free    0.0       Everyone
# 10838     NaN        3      9.5      1000  Free    0.0       Everyone
# 10839     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# 10836          Education   2017-07-25                1.48          4.1 and up
# 10837          Education   2018-07-06                 1.0          4.1 and up
# 10838            Medical   2017-01-20                 1.0          2.2 and up
# 10839  Books & Reference   2015-01-19  Varies with device  Varies with device
# 10840          Lifestyle   2018-07-25  Varies with device  Varies with device
#
#        Year
# 10836  2017
# 10837  2018
# 10838  2017
# 10839  2015
# 10840  2018

# %%
df_clean[df_clean.duplicated(subset="App")]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10715                  FarmersOnly Dating         DATING     3.0     1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10730                         FP Notebook        MEDICAL     4.5      410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10768                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# 229        NaN   5000000  Free    0.0       Everyone       Business
# 236        NaN  10000000  Free    0.0       Everyone       Business
# 239        NaN   5000000  Free    0.0       Everyone       Business
# 256    37000.0  10000000  Free    0.0       Everyone       Business
# 261        NaN   1000000  Free    0.0       Everyone       Business
# ...        ...       ...   ...    ...            ...            ...
# 10715      1.4    100000  Free    0.0     Mature 17+         Dating
# 10720      4.0   1000000  Free    0.0       Everyone  Communication
# 10730  60000.0     50000  Free    0.0       Everyone        Medical
# 10753  12000.0   1000000  Free    0.0       Everyone       Shopping
# 10768  24000.0     10000  Free    0.0       Everyone        Medical
#
#       Last Updated         Current Ver         Android Ver  Year
# 229     2018-02-26  Varies with device        4.0.3 and up  2018
# 236     2018-07-31  Varies with device  Varies with device  2018
# 239     2018-07-24    2.19.0.204537701          4.4 and up  2018
# 256     2018-07-20      4.1.28165.0716          4.0 and up  2018
# 261     2018-07-16           4.3.0.508          4.4 and up  2018
# ...            ...                 ...                 ...   ...
# 10715   2016-02-25                 2.2          4.0 and up  2016
# 10720   2018-07-06                 5.2          5.0 and up  2018
# 10730   2018-03-24           2.1.0.372          4.4 and up  2018
# 10753   2018-07-30                 3.9          4.4 and up  2018
# 10768   2018-06-22               2.3.1          5.0 and up  2018
#
# [1181 rows x 14 columns]

# %%
df_clean = df_clean.sort_values("Reviews",ascending=False,ignore_index=True)

# %%
df_clean
# Out:
#                                    App       Category  Rating   Reviews  \
# 0                             Facebook         SOCIAL     4.1  78158306
# 1                             Facebook         SOCIAL     4.1  78128208
# 2                   WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 3                   WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 4                   WhatsApp Messenger  COMMUNICATION     4.4  69109672
# ...                                ...            ...     ...       ...
# 10835           Free CW TN Videos 2018         FAMILY     NaN         0
# 10836         CT Pulmonary Angiography        MEDICAL     NaN         0
# 10837  POCKET ATLAS CARDIAC MRI AND CT        MEDICAL     NaN         0
# 10838                   All Star Of CW         FAMILY     NaN         0
# 10839                Ag Across America         FAMILY     NaN         0
#
#           Size    Installs  Type  Price Content Rating                 Genres  \
# 0          NaN  1000000000  Free    0.0           Teen                 Social
# 1          NaN  1000000000  Free    0.0           Teen                 Social
# 2          NaN  1000000000  Free    0.0       Everyone          Communication
# 3          NaN  1000000000  Free    0.0       Everyone          Communication
# 4          NaN  1000000000  Free    0.0       Everyone          Communication
# ...        ...         ...   ...    ...            ...                    ...
# 10835      4.8          10  Free    0.0       Everyone          Entertainment
# 10836      4.9         100  Free    0.0       Everyone                Medical
# 10837      4.8          50  Free    0.0       Everyone                Medical
# 10838      2.4          10  Free    0.0       Everyone           Role Playing
# 10839  15000.0          10  Free    0.0       Everyone  Educational;Education
#
#       Last Updated         Current Ver         Android Ver  Year
# 0       2018-08-03  Varies with device  Varies with device  2018
# 1       2018-08-03  Varies with device  Varies with device  2018
# 2       2018-08-03  Varies with device  Varies with device  2018
# 3       2018-08-03  Varies with device  Varies with device  2018
# 4       2018-08-03  Varies with device  Varies with device  2018
# ...            ...                 ...                 ...   ...
# 10835   2018-07-28                 1.0          3.2 and up  2018
# 10836   2018-03-24                 1.0          4.0 and up  2018
# 10837   2018-07-18                 1.0          4.0 and up  2018
# 10838   2018-02-06                2.03        4.0.3 and up  2018
# 10839   2018-05-15               1.0.0          4.1 and up  2018
#
# [10840 rows x 14 columns]

# %%
df_clean = df_clean.drop_duplicates(subset="App",keep="first",ignore_index=True)

# %%
df_clean
# Out:
#                                            App       Category  Rating  \
# 0                                     Facebook         SOCIAL     4.1
# 1                           WhatsApp Messenger  COMMUNICATION     4.4
# 2                                    Instagram         SOCIAL     4.5
# 3     Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4                               Clash of Clans           GAME     4.6
# ...                                        ...            ...     ...
# 9654                    Free CW TN Videos 2018         FAMILY     NaN
# 9655                  CT Pulmonary Angiography        MEDICAL     NaN
# 9656           POCKET ATLAS CARDIAC MRI AND CT        MEDICAL     NaN
# 9657                            All Star Of CW         FAMILY     NaN
# 9658                         Ag Across America         FAMILY     NaN
#
#        Reviews     Size    Installs  Type  Price Content Rating  \
# 0     78158306      NaN  1000000000  Free    0.0           Teen
# 1     69119316      NaN  1000000000  Free    0.0       Everyone
# 2     66577446      NaN  1000000000  Free    0.0           Teen
# 3     56646578      NaN  1000000000  Free    0.0       Everyone
# 4     44893888  98000.0   100000000  Free    0.0   Everyone 10+
# ...        ...      ...         ...   ...    ...            ...
# 9654         0      4.8          10  Free    0.0       Everyone
# 9655         0      4.9         100  Free    0.0       Everyone
# 9656         0      4.8          50  Free    0.0       Everyone
# 9657         0      2.4          10  Free    0.0       Everyone
# 9658         0  15000.0          10  Free    0.0       Everyone
#
#                      Genres Last Updated         Current Ver  \
# 0                    Social   2018-08-03  Varies with device
# 1             Communication   2018-08-03  Varies with device
# 2                    Social   2018-07-31  Varies with device
# 3             Communication   2018-08-01  Varies with device
# 4                  Strategy   2018-07-15           10.322.16
# ...                     ...          ...                 ...
# 9654          Entertainment   2018-07-28                 1.0
# 9655                Medical   2018-03-24                 1.0
# 9656                Medical   2018-07-18                 1.0
# 9657           Role Playing   2018-02-06                2.03
# 9658  Educational;Education   2018-05-15               1.0.0
#
#              Android Ver  Year
# 0     Varies with device  2018
# 1     Varies with device  2018
# 2     Varies with device  2018
# 3     Varies with device  2018
# 4             4.1 and up  2018
# ...                  ...   ...
# 9654          3.2 and up  2018
# 9655          4.0 and up  2018
# 9656          4.0 and up  2018
# 9657        4.0.3 and up  2018
# 9658          4.1 and up  2018
#
# [9659 rows x 14 columns]

# %% [markdown]
# # EDA

# %%
df_clean["Price"].unique()
# Out:
# array([  0.  ,   6.99,   0.99,   2.99,   1.99,   2.49,   4.99,   5.99,
#          4.49,   9.99,   3.99,   1.49,   3.95,   7.99,   3.49,   8.99,
#         13.99,  19.99,  11.99,  12.99,   2.9 ,  17.99, 399.99,  29.99,
#         14.99,   2.95,   4.77,  24.99,   3.9 ,   2.5 ,   3.28,   1.2 ,
#          2.59,   9.  ,   1.59,   1.  ,   5.49,  18.99, 299.99,   1.97,
#        400.  ,  16.99, 389.99,  33.99,  10.  ,  10.99,   4.84,  37.99,
#          1.61,   8.49,   4.6 ,  79.99,   4.29,   1.7 ,   1.5 ,   1.29,
#         19.4 ,   3.08, 379.99,   2.56,  15.46,   7.49,   4.59,   2.  ,
#         14.  ,   6.49,  15.99,   3.88,  74.99,  39.99,  89.99,   3.02,
#          1.75,   5.  ,  19.9 ,   2.6 ,   4.8 ,   1.26,  46.99,   1.76,
#          3.04,   4.85, 200.  ,  28.99, 154.99,   1.96, 394.99,  30.99,
#          3.61, 109.99,  25.99,   1.04])

# %%
df_clean["Price"].max()
# Out:
# 400.0

# %%
plt.figure(figsize=(10,6))
sns.barplot(y=df_clean["Price"],x=df_clean["Reviews"])
plt.show()

# %%
bins_price = [-0.1,0,10,50,150,np.inf]
labels_price = ["Free","Cheap","Mid","High","Exspensive"]

# %%
df_clean["Price Category"] = pd.cut(df_clean["Price"],bins=bins_price,labels=labels_price,ordered=True)
# Out:
# C:\Users\gokhan\AppData\Local\Temp\ipykernel_22988\1177334454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Price Category"] = pd.cut(df_clean["Price"],bins=bins_price,labels=labels_price,ordered=True)

# %%
df_clean
# Out:
#                                            App       Category  Rating  \
# 0                                     Facebook         SOCIAL     4.1
# 1                           WhatsApp Messenger  COMMUNICATION     4.4
# 2                                    Instagram         SOCIAL     4.5
# 3     Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4                               Clash of Clans           GAME     4.6
# ...                                        ...            ...     ...
# 9654                    Free CW TN Videos 2018         FAMILY     NaN
# 9655                  CT Pulmonary Angiography        MEDICAL     NaN
# 9656           POCKET ATLAS CARDIAC MRI AND CT        MEDICAL     NaN
# 9657                            All Star Of CW         FAMILY     NaN
# 9658                         Ag Across America         FAMILY     NaN
#
#        Reviews     Size    Installs  Type  Price Content Rating  \
# 0     78158306      NaN  1000000000  Free    0.0           Teen
# 1     69119316      NaN  1000000000  Free    0.0       Everyone
# 2     66577446      NaN  1000000000  Free    0.0           Teen
# 3     56646578      NaN  1000000000  Free    0.0       Everyone
# 4     44893888  98000.0   100000000  Free    0.0   Everyone 10+
# ...        ...      ...         ...   ...    ...            ...
# 9654         0      4.8          10  Free    0.0       Everyone
# 9655         0      4.9         100  Free    0.0       Everyone
# 9656         0      4.8          50  Free    0.0       Everyone
# 9657         0      2.4          10  Free    0.0       Everyone
# 9658         0  15000.0          10  Free    0.0       Everyone
#
#                      Genres Last Updated         Current Ver  \
# 0                    Social   2018-08-03  Varies with device
# 1             Communication   2018-08-03  Varies with device
# 2                    Social   2018-07-31  Varies with device
# 3             Communication   2018-08-01  Varies with device
# 4                  Strategy   2018-07-15           10.322.16
# ...                     ...          ...                 ...
# 9654          Entertainment   2018-07-28                 1.0
# 9655                Medical   2018-03-24                 1.0
# 9656                Medical   2018-07-18                 1.0
# 9657           Role Playing   2018-02-06                2.03
# 9658  Educational;Education   2018-05-15               1.0.0
#
#              Android Ver  Year Price Category
# 0     Varies with device  2018           Free
# 1     Varies with device  2018           Free
# 2     Varies with device  2018           Free
# 3     Varies with device  2018           Free
# 4             4.1 and up  2018           Free
# ...                  ...   ...            ...
# 9654          3.2 and up  2018           Free
# 9655          4.0 and up  2018           Free
# 9656          4.0 and up  2018           Free
# 9657        4.0.3 and up  2018           Free
# 9658          4.1 and up  2018           Free
#
# [9659 rows x 15 columns]

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df_clean["Price Category"],y=df_clean["Reviews"])
plt.yscale("log")
plt.show()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8431 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
#  13  Year            9659 non-null   int32
#  14  Price Category  9659 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(3), int32(1), int64(2), object(7)
# memory usage: 1.0+ MB

# %%
df_clean.shape
# Out:
# (9659, 15)

# %%
numeric_features = [
    feature for feature in df_clean.columns 
    if df_clean[feature].dtype != "O" and not isinstance(df_clean[feature].dtype, pd.CategoricalDtype)
]
categorical_features = [
    feature for feature in df_clean.columns 
    if df_clean[feature].dtype == "O" or isinstance(df_clean[feature].dtype, pd.CategoricalDtype)
]

# %%
print(numeric_features)
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Last Updated', 'Year']

# %%
print(categorical_features)
# Out:
# ['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver', 'Price Category']

# %%
df_clean["Current Ver"].dtype
# Out:
# dtype('O')

# %%
plt.figure(figsize=(15,10))
for i in range(len(numeric_features)):
    plt.subplot(3,3,i+1)
    sns.kdeplot(df_clean[numeric_features[i]], color="g", fill=True)
    plt.xlabel(f"{numeric_features[i]}")
    plt.tight_layout()
plt.show()

# %%
df_clean
# Out:
#                                            App       Category  Rating  \
# 0                                     Facebook         SOCIAL     4.1
# 1                           WhatsApp Messenger  COMMUNICATION     4.4
# 2                                    Instagram         SOCIAL     4.5
# 3     Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4                               Clash of Clans           GAME     4.6
# ...                                        ...            ...     ...
# 9654                    Free CW TN Videos 2018         FAMILY     NaN
# 9655                  CT Pulmonary Angiography        MEDICAL     NaN
# 9656           POCKET ATLAS CARDIAC MRI AND CT        MEDICAL     NaN
# 9657                            All Star Of CW         FAMILY     NaN
# 9658                         Ag Across America         FAMILY     NaN
#
#        Reviews     Size    Installs  Type  Price Content Rating  \
# 0     78158306      NaN  1000000000  Free    0.0           Teen
# 1     69119316      NaN  1000000000  Free    0.0       Everyone
# 2     66577446      NaN  1000000000  Free    0.0           Teen
# 3     56646578      NaN  1000000000  Free    0.0       Everyone
# 4     44893888  98000.0   100000000  Free    0.0   Everyone 10+
# ...        ...      ...         ...   ...    ...            ...
# 9654         0      4.8          10  Free    0.0       Everyone
# 9655         0      4.9         100  Free    0.0       Everyone
# 9656         0      4.8          50  Free    0.0       Everyone
# 9657         0      2.4          10  Free    0.0       Everyone
# 9658         0  15000.0          10  Free    0.0       Everyone
#
#                      Genres Last Updated         Current Ver  \
# 0                    Social   2018-08-03  Varies with device
# 1             Communication   2018-08-03  Varies with device
# 2                    Social   2018-07-31  Varies with device
# 3             Communication   2018-08-01  Varies with device
# 4                  Strategy   2018-07-15           10.322.16
# ...                     ...          ...                 ...
# 9654          Entertainment   2018-07-28                 1.0
# 9655                Medical   2018-03-24                 1.0
# 9656                Medical   2018-07-18                 1.0
# 9657           Role Playing   2018-02-06                2.03
# 9658  Educational;Education   2018-05-15               1.0.0
#
#              Android Ver  Year Price Category
# 0     Varies with device  2018           Free
# 1     Varies with device  2018           Free
# 2     Varies with device  2018           Free
# 3     Varies with device  2018           Free
# 4             4.1 and up  2018           Free
# ...                  ...   ...            ...
# 9654          3.2 and up  2018           Free
# 9655          4.0 and up  2018           Free
# 9656          4.0 and up  2018           Free
# 9657        4.0.3 and up  2018           Free
# 9658          4.1 and up  2018           Free
#
# [9659 rows x 15 columns]

# %%
plt.figure(figsize=(20,6))

category = ["Type","Content Rating"]

for i in range(len(category)):
    plt.subplot(1,2,i+1)
    sns.countplot(x=df_clean[category[i]], color="g", fill=True)
    plt.xlabel(f"{category[i]}")
    
plt.show()

# %%
df_clean["Category"].unique()
# Out:
# array(['SOCIAL', 'COMMUNICATION', 'GAME', 'TOOLS', 'VIDEO_PLAYERS',
#        'NEWS_AND_MAGAZINES', 'PHOTOGRAPHY', 'FAMILY', 'TRAVEL_AND_LOCAL',
#        'PERSONALIZATION', 'MAPS_AND_NAVIGATION', 'SHOPPING',
#        'ENTERTAINMENT', 'PRODUCTIVITY', 'HEALTH_AND_FITNESS', 'SPORTS',
#        'BOOKS_AND_REFERENCE', 'LIFESTYLE', 'WEATHER', 'FINANCE',
#        'BUSINESS', 'EDUCATION', 'FOOD_AND_DRINK', 'COMICS', 'PARENTING',
#        'DATING', 'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO', 'ART_AND_DESIGN',
#        'AUTO_AND_VEHICLES', 'MEDICAL', 'BEAUTY', 'EVENTS'], dtype=object)

# %%
df_clean["Genres"].unique()
# Out:
# array(['Social', 'Communication', 'Strategy', 'Tools', 'Arcade',
#        'Video Players & Editors', 'Casual', 'Sports', 'News & Magazines',
#        'Action', 'Photography', 'Adventure', 'Casual;Action & Adventure',
#        'Travel & Local', 'Racing', 'Personalization', 'Maps & Navigation',
#        'Entertainment', 'Trivia', 'Education;Education', 'Shopping',
#        'Productivity', 'Health & Fitness', 'Adventure;Action & Adventure',
#        'Simulation', 'Books & Reference', 'Lifestyle', 'Role Playing',
#        'Arcade;Action & Adventure', 'Weather', 'Puzzle', 'Casino', 'Card',
#        'Word', 'Puzzle;Action & Adventure', 'Sports;Action & Adventure',
#        'Board', 'Finance', 'Puzzle;Brain Games',
#        'Racing;Action & Adventure', 'Business', 'Education',
#        'Food & Drink', 'Educational;Pretend Play', 'Comics',
#        'Card;Action & Adventure', 'Music',
#        'Educational;Action & Adventure', 'Parenting',
#        'Simulation;Action & Adventure', 'Role Playing;Action & Adventure',
#        'Action;Action & Adventure', 'Dating',
#        'Entertainment;Music & Video', 'House & Home',
#        'Entertainment;Creativity', 'Casual;Pretend Play',
#        'Tools;Education', 'Libraries & Demo', 'Casual;Creativity',
#        'Art & Design', 'Adventure;Education', 'Education;Brain Games',
#        'Auto & Vehicles', 'Entertainment;Brain Games',
#        'Video Players & Editors;Creativity', 'Medical',
#        'Role Playing;Pretend Play', 'Role Playing;Brain Games',
#        'Lifestyle;Pretend Play', 'Strategy;Creativity',
#        'Entertainment;Action & Adventure',
#        'Video Players & Editors;Music & Video', 'Beauty',
#        'Educational;Education', 'Educational', 'Puzzle;Creativity',
#        'Board;Action & Adventure', 'Simulation;Pretend Play',
#        'Entertainment;Pretend Play', 'Education;Pretend Play',
#        'Educational;Brain Games', 'Music;Music & Video',
#        'Casual;Brain Games', 'Events', 'Casual;Music & Video',
#        'Education;Music & Video', 'Simulation;Education',
#        'Health & Fitness;Action & Adventure', 'Arcade;Pretend Play',
#        'Strategy;Action & Adventure', 'Educational;Creativity',
#        'Art & Design;Creativity', 'Casual;Education',
#        'Parenting;Music & Video', 'Education;Creativity',
#        'Education;Action & Adventure', 'Health & Fitness;Education',
#        'Entertainment;Education', 'Adventure;Brain Games',
#        'Parenting;Education', 'Board;Brain Games',
#        'Parenting;Brain Games', 'Communication;Creativity',
#        'Lifestyle;Education', 'Racing;Pretend Play', 'Strategy;Education',
#        'Music & Audio;Music & Video', 'Art & Design;Pretend Play',
#        'Travel & Local;Action & Adventure', 'Puzzle;Education',
#        'Comics;Creativity', 'Books & Reference;Education',
#        'Art & Design;Action & Adventure', 'Books & Reference;Creativity',
#        'Trivia;Education', 'Board;Pretend Play', 'Role Playing;Education'],
#       dtype=object)

# %%
plt.figure(figsize=(10,15))
sns.countplot(df_clean["Category"],color="r")
plt.show()

# %%
df_clean["Category"].value_counts()
# Out:
# Category
# FAMILY                 1876
# GAME                    945
# TOOLS                   829
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  170
# VIDEO_PLAYERS           164
# MAPS_AND_NAVIGATION     131
# FOOD_AND_DRINK          112
# EDUCATION               106
# ENTERTAINMENT            87
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           73
# EVENTS                   64
# ART_AND_DESIGN           61
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,15))
sns.barplot(x=df_clean["Installs"],y=df_clean["Category"],color="b", estimator="sum",errorbar=None)
plt.show()

# %%
df_cat_ınstalls = df_clean.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()

# %%
df_cat_ınstalls
# Out:
#                Category     Installs
# 0                  GAME  13447924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8102771915
# 3                FAMILY   6231542505
# 4          PRODUCTIVITY   5793091369
# 5                SOCIAL   5487867902
# 6           PHOTOGRAPHY   4658147655
# 7         VIDEO_PLAYERS   3931902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10  BOOKS_AND_REFERENCE   1665969576
# 11      PERSONALIZATION   1532494782
# 12             SHOPPING   1400348785
# 13   HEALTH_AND_FITNESS   1144022512
# 14               SPORTS   1096474498
# 15        ENTERTAINMENT    989660000
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21       FOOD_AND_DRINK    211798751
# 22            EDUCATION    189951000
# 23               DATING    140925107
# 24       ART_AND_DESIGN    113238100
# 25       HOUSE_AND_HOME     97202461
# 26    AUTO_AND_VEHICLES     53130211
# 27   LIBRARIES_AND_DEMO     52995910
# 28               COMICS     44981150
# 29              MEDICAL     38293077
# 30            PARENTING     31521110
# 31               BEAUTY     27197050
# 32               EVENTS     15973161

# %%
df2 = df_cat_ınstalls.head(10)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df2["Installs"],y=df2["Category"],color="b", estimator="sum",errorbar=None)
plt.show()

# %%
df_app_category = df_clean.groupby(['Category' ,'App'])['Installs'].sum().reset_index()
df_app_category = df_app_category.sort_values('Installs', ascending = False)
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ,'TOOLS']
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = df_app_category[df_app_category.Category == app]

    #get only 5
    df_top_5 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df_top_5,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %%
rating_df = df_clean.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()
top_rated_apps = rating_df[rating_df.Rating == 5.0]

# %%
top_rated_apps.shape
# Out:
# (271, 4)

# %%
top_rated_apps
# Out:
#                Category  Installs                                      App  \
# 0        ART_AND_DESIGN       100  Spring flowers theme couleurs d t space
# 1                FAMILY        10                    Hey AJ! It's Bedtime!
# 2                FAMILY        10                              DN Employee
# 3                 TOOLS      1000                                  CL REPL
# 4                FAMILY        10                            Story Time FD
# ..                  ...       ...                                      ...
# 266  HEALTH_AND_FITNESS        50                               EF Academy
# 267              FAMILY       100                                DV ASSIST
# 268              FAMILY       100                      Cr Aviation Academy
# 269              FAMILY       100        DC N COMPANY ENTERTAINMENT RADIO!
# 270              FAMILY       100                             Foothills CP
#
#      Rating
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
# ..      ...
# 266     5.0
# 267     5.0
# 268     5.0
# 269     5.0
# 270     5.0
#
# [271 rows x 4 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8431 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
#  13  Year            9659 non-null   int32
#  14  Price Category  9659 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(3), int32(1), int64(2), object(7)
# memory usage: 1.0+ MB

# %%
df_clean['Android Ver']
# Out:
# 0       Varies with device
# 1       Varies with device
# 2       Varies with device
# 3       Varies with device
# 4               4.1 and up
#                ...
# 9654            3.2 and up
# 9655            4.0 and up
# 9656            4.0 and up
# 9657          4.0.3 and up
# 9658            4.1 and up
# Name: Android Ver, Length: 9659, dtype: object

# %%
df_clean['Android Ver']=df_clean['Android Ver'].replace('and up', '', regex=True)
# Out:
# C:\Users\gokhan\AppData\Local\Temp\ipykernel_22988\1970963373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Android Ver']=df_clean['Android Ver'].replace('and up', '', regex=True)

# %%
df_clean['Android Ver']
# Out:
# 0       Varies with device
# 1       Varies with device
# 2       Varies with device
# 3       Varies with device
# 4                     4.1
#                ...
# 9654                  3.2
# 9655                  4.0
# 9656                  4.0
# 9657                4.0.3
# 9658                  4.1
# Name: Android Ver, Length: 9659, dtype: object

# %%
df_clean['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1                   2205
# 4.0.3                 1393
# 4.0                   1286
# Varies with device     991
# 4.4                    818
# 2.3                    614
# 5.0                    512
# 4.2                    372
# 2.3.3                  273
# 2.2                    239
# 3.0                    230
# 4.3                    221
# 2.1                    133
# 1.6                    116
# 6.0                     54
# 7.0                     42
# 3.2                     36
# 2.0                     32
# 5.1                     22
# 1.5                     20
# 4.4W                    11
# 3.1                     10
# 2.0.1                    7
# 8.0                      6
# 7.1                      3
# 5.0 - 8.0                2
# 4.0.3 - 7.1.1            2
# 1.0                      2
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 7.0 - 7.1.1              1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
df_clean['Android Ver']=df_clean['Android Ver'].replace('Varies with device', '', regex=True).replace('W', '', regex=True).replace('', np.nan)
# Out:
# C:\Users\gokhan\AppData\Local\Temp\ipykernel_22988\3421703448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Android Ver']=df_clean['Android Ver'].replace('Varies with device', '', regex=True).replace('W', '', regex=True).replace('', np.nan)

# %%
df_clean['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1              2205
# 4.0.3            1393
# 4.0              1286
# 4.4               829
# 2.3               614
# 5.0               512
# 4.2               372
# 2.3.3             273
# 2.2               239
# 3.0               230
# 4.3               221
# 2.1               133
# 1.6               116
# 6.0                54
# 7.0                42
# 3.2                36
# 2.0                32
# 5.1                22
# 1.5                20
# 3.1                10
# 2.0.1               7
# 8.0                 6
# 7.1                 3
# 4.0.3 - 7.1.1       2
# 5.0 - 8.0           2
# 1.0                 2
# 4.1 - 7.1.1         1
# 5.0 - 6.0           1
# 7.0 - 7.1.1         1
# 2.2 - 7.1.1         1
# 5.0 - 7.1.1         1
# Name: count, dtype: int64

# %%
df_clean.loc[df_clean['Android Ver'].str.contains('-') == True]
# Out:
#                                 App         Category  Rating  Reviews  \
# 396             Google Now Launcher            TOOLS     4.2   857215
# 828   Photo Collage - Layout Editor      PHOTOGRAPHY     4.5   285788
# 1044                     Browser 4G    COMMUNICATION     4.3   192948
# 2222         Web Browser & Explorer    COMMUNICATION     4.0    36901
# 2626                ASUS Quick Memo     PRODUCTIVITY     4.5    23089
# 5551           My Style CM 13 Theme  PERSONALIZATION     4.5      314
# 6329                ZenUI Safeguard        LIFESTYLE     4.5      100
# 8297                      EF Jumper             GAME     NaN        4
# 8818             EY Catalyst Reader         BUSINESS     NaN        1
#
#          Size   Installs  Type  Price Content Rating           Genres  \
# 396       7.9  100000000  Free    0.0       Everyone            Tools
# 828   46000.0   10000000  Free    0.0       Everyone      Photography
# 1044      6.6   10000000  Free    0.0       Everyone    Communication
# 2222      6.6    5000000  Free    0.0       Everyone    Communication
# 2626      1.6   10000000  Free    0.0       Everyone     Productivity
# 5551  11000.0      10000  Free    0.0       Everyone  Personalization
# 6329      7.1    1000000  Free    0.0       Everyone        Lifestyle
# 8297      5.1        100  Free    0.0       Everyone           Arcade
# 8818      8.4          5  Free    0.0       Everyone         Business
#
#      Last Updated       Current Ver    Android Ver  Year Price Category
# 396    2017-12-07         1.4.large    4.1 - 7.1.1  2017           Free
# 828    2017-12-04    1.8.0.170824_9      5.0 - 8.0  2017           Free
# 1044   2018-06-19            24.6.6  4.0.3 - 7.1.1  2018           Free
# 2222   2018-07-04            11.8.6  4.0.3 - 7.1.1  2018           Free
# 2626   2018-04-11  1.10.0.33_180403      5.0 - 8.0  2018           Free
# 5551   2016-09-08               1.9      5.0 - 6.0  2016           Free
# 6329   2018-05-09   1.0.0.21_180410    7.0 - 7.1.1  2018           Free
# 8297   2017-07-13          Build 12    2.2 - 7.1.1  2017           Free
# 8818   2018-04-10             1.2.1    5.0 - 7.1.1  2018           Free

# %%
df_clean=df_clean.loc[df_clean['Android Ver'].str.contains('-') == False]

# %%
df_clean['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1       2205
# 4.0.3     1393
# 4.0       1286
# 4.4        829
# 2.3        614
# 5.0        512
# 4.2        372
# 2.3.3      273
# 2.2        239
# 3.0        230
# 4.3        221
# 2.1        133
# 1.6        116
# 6.0         54
# 7.0         42
# 3.2         36
# 2.0         32
# 5.1         22
# 1.5         20
# 3.1         10
# 2.0.1        7
# 8.0          6
# 7.1          3
# 1.0          2
# Name: count, dtype: int64

# %%
mean_genres_installs=df_clean.groupby("Genres")["Installs"].mean()/1_000_000

# %%
mean_genres_installs
# Out:
# Genres
# Action                                   11.255844
# Action;Action & Adventure                 3.910955
# Adventure                                 4.064319
# Adventure;Action & Adventure             21.230000
# Adventure;Brain Games                     0.100000
#                                            ...
# Video Players & Editors                   7.093219
# Video Players & Editors;Creativity        5.000000
# Video Players & Editors;Music & Video     5.000000
# Weather                                   2.270176
# Word                                      4.956450
# Name: Installs, Length: 117, dtype: float64

# %%
mean_genres_installs = mean_genres_installs.to_dict()

# %%
df_clean["Genres Encoded"]=df_clean["Genres"].map(mean_genres_installs)
# Out:
# C:\Users\gokhan\AppData\Local\Temp\ipykernel_22988\1397726103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Genres Encoded"]=df_clean["Genres"].map(mean_genres_installs)

# %%
df_clean["Genres Encoded"]
# Out:
# 4       10.102557
# 6       20.540684
# 9       10.102557
# 10      17.919876
# 11      10.468861
#           ...
# 9654     2.835731
# 9655     0.093245
# 9656     0.093245
# 9657     3.206220
# 9658     1.661391
# Name: Genres Encoded, Length: 8657, dtype: float64

# %%
df_clean
# Out:
#                                               App       Category  Rating  \
# 4                                  Clash of Clans           GAME     4.6
# 6                                  Subway Surfers           GAME     4.5
# 9                                    Clash Royale           GAME     4.6
# 10                               Candy Crush Saga           GAME     4.4
# 11    UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# ...                                           ...            ...     ...
# 9654                       Free CW TN Videos 2018         FAMILY     NaN
# 9655                     CT Pulmonary Angiography        MEDICAL     NaN
# 9656              POCKET ATLAS CARDIAC MRI AND CT        MEDICAL     NaN
# 9657                               All Star Of CW         FAMILY     NaN
# 9658                            Ag Across America         FAMILY     NaN
#
#        Reviews     Size    Installs  Type  Price Content Rating  \
# 4     44893888  98000.0   100000000  Free    0.0   Everyone 10+
# 6     27725352  76000.0  1000000000  Free    0.0   Everyone 10+
# 9     23136735  97000.0   100000000  Free    0.0   Everyone 10+
# 10    22430188  74000.0   500000000  Free    0.0       Everyone
# 11    17714850  40000.0   500000000  Free    0.0           Teen
# ...        ...      ...         ...   ...    ...            ...
# 9654         0      4.8          10  Free    0.0       Everyone
# 9655         0      4.9         100  Free    0.0       Everyone
# 9656         0      4.8          50  Free    0.0       Everyone
# 9657         0      2.4          10  Free    0.0       Everyone
# 9658         0  15000.0          10  Free    0.0       Everyone
#
#                      Genres Last Updated  Current Ver Android Ver  Year  \
# 4                  Strategy   2018-07-15    10.322.16        4.1   2018
# 6                    Arcade   2018-07-12       1.90.0        4.1   2018
# 9                  Strategy   2018-06-27        2.3.2        4.1   2018
# 10                   Casual   2018-07-05    1.129.0.2        4.1   2018
# 11            Communication   2018-08-02  12.8.5.1121        4.0   2018
# ...                     ...          ...          ...         ...   ...
# 9654          Entertainment   2018-07-28          1.0        3.2   2018
# 9655                Medical   2018-03-24          1.0        4.0   2018
# 9656                Medical   2018-07-18          1.0        4.0   2018
# 9657           Role Playing   2018-02-06         2.03      4.0.3   2018
# 9658  Educational;Education   2018-05-15        1.0.0        4.1   2018
#
#      Price Category  Genres Encoded
# 4              Free       10.102557
# 6              Free       20.540684
# 9              Free       10.102557
# 10             Free       17.919876
# 11             Free       10.468861
# ...             ...             ...
# 9654           Free        2.835731
# 9655           Free        0.093245
# 9656           Free        0.093245
# 9657           Free        3.206220
# 9658           Free        1.661391
#
# [8657 rows x 16 columns]
